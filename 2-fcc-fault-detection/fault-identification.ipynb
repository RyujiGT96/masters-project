# %%
import pandas as pd
import numpy as np

# %%
df_test1 = pd.read_csv("datasets/original/CONV_DATA_SET_2_REV_1.csv", delimiter=";", header=0, skiprows=[1, 2])

# %%
df_test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14401 entries, 0 to 14400
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PERIODO    14401 non-null  object
#  1   LC2401     14401 non-null  float64
#  2   LC2401SV   14401 non-null  int64
#  3   LC2401MV   14401 non-null  float64
#  4   ZI2403     14401 non-null  float64
#  5   PDC2477    14401 non-null  float64
#  6   PDC2477SV  14401 non-null  float64
#  7   PDC2477MV  14401 non-null  int64
#  8   FI24157    14401 non-null  float64
#  9   FC24154    14401 non-null  float64
#  10  PC2471     14401 non-null  float64
#  11  PI2470     14401 non-null  float64
#  12  TC2407     14401 non-null  float64
#  13  TC2407SV   14401 non-null  float64
#  14  TC2407MV   14401 non-null  float64
#  15  TC2411     14401 non-null  float64
#  16  FX2430SV   14401 non-null  float64
#  17  CIRCCAT24  14401 non-null  float64
# dtypes: float64(15), int64(2), object(1)
# ...

# %%
df_test1_faults = df_test1[(df_test1['LC2401'] > 6) | (df_test1['LC2401'] < 4)]

# %%
df_test1_faults
# Out:
#                 PERIODO    LC2401  LC2401SV   LC2401MV     ZI2403   PDC2477  \
# 719    15/05/2011 11:59  6.187165         5  41.421471  41.049580  0.720817
# 1335   15/05/2011 22:15  6.193666         5  41.715836  41.200577  0.674332
# 1422   15/05/2011 23:42  6.412030         5  42.784664  41.862389  0.617861
# 1423   15/05/2011 23:43  7.844289         5  45.971382  41.861183  0.351488
# 1424   15/05/2011 23:44  8.187556         5  47.323505  41.859978  0.325430
# ...                 ...       ...       ...        ...        ...       ...
# 13443  24/05/2011 08:03  7.841220         5  48.083702  44.128143  0.439353
# 13444  24/05/2011 08:04  2.210964         5  44.783012  44.224480  0.638675
# 13445  24/05/2011 08:05  2.371205         5  41.573292  44.201832  0.673972
# 13446  24/05/2011 08:06  2.779308         5  41.703892  44.155071  0.704856
# 13447  24/05/2011 08:07  3.537409         5  42.042366  44.108315  0.713264
#
# ...

# %%
df_test2 = pd.read_csv("datasets/original/CONV_DATA_SET_3_REV_1.csv", delimiter=";", header=0, skiprows=[1, 2])

# %%
df_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12961 entries, 0 to 12960
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PERIODO    12961 non-null  object
#  1   LC2401     12961 non-null  float64
#  2   LC2401SV   12961 non-null  float64
#  3   LC2401MV   12961 non-null  float64
#  4   ZI2403     12961 non-null  float64
#  5   PDC2477    12961 non-null  float64
#  6   PDC2477SV  12961 non-null  float64
#  7   PDC2477MV  12961 non-null  int64
#  8   FI24157    12961 non-null  float64
#  9   FC24154    12961 non-null  float64
#  10  PC2471     12961 non-null  float64
#  11  PI2470     12961 non-null  float64
#  12  TC2407     12961 non-null  float64
#  13  TC2407SV   12961 non-null  float64
#  14  TC2407MV   12961 non-null  float64
#  15  TC2411     12961 non-null  float64
#  16  FX2430SV   12961 non-null  float64
#  17  CIRCCAT24  12961 non-null  float64
# dtypes: float64(16), int64(1), object(1)
# ...

# %%
df_test2_faults = df_test2[(df_test2['LC2401'] > 6) | (df_test2['LC2401'] < 4)]

# %%
df_test2_faults
# Out:
#                 PERIODO    LC2401  LC2401SV   LC2401MV     ZI2403   PDC2477  \
# 650    01/04/2012 10:50  3.982439  5.038079  41.696983  41.536659  0.768973
# 686    01/04/2012 11:26  3.649686  5.038079  40.032520  41.523327  0.815463
# 943    01/04/2012 15:43  6.118585  5.038079  42.546574  42.291100  0.737473
# 944    01/04/2012 15:44  8.036281  5.038079  45.449226  42.278698  0.533266
# 945    01/04/2012 15:45  2.609216  5.038079  40.870575  42.266300  0.711840
# ...                 ...       ...       ...        ...        ...       ...
# 12607  09/04/2012 18:07  2.624392  5.038079  41.149113  43.886776  0.667695
# 12840  09/04/2012 22:00  6.072597  5.038079  41.395084  41.790455  0.783695
# 12841  09/04/2012 22:01  6.345232  5.038079  42.116508  41.796139  0.690992
# 12842  09/04/2012 22:02  6.617867  5.038079  43.511612  41.801823  0.704497
# 12843  09/04/2012 22:03  3.607115  5.038079  40.543041  41.807510  0.723445
#
# ...

# %%
# df_test1_faults.to_csv('datasets/original/CONV_DATA_SET_2_REV_1_FAULTS.csv', index=False, sep=';')
# df_test2_faults.to_csv('datasets/original/CONV_DATA_SET_3_REV_1_FAULTS.csv', index=False, sep=';')
